# %%
a=[n for n in 'python']

# %%
print(a)
# Out:
# ['p', 'y', 't', 'h', 'o', 'n']

# %%
a.append('H')

# %%
print(a)
# Out:
# ['p', 'y', 't', 'h', 'o', 'n', 'H']

# %%
a.reverse()

# %%
print(a)
# Out:
# ['H', 'n', 'o', 'h', 't', 'y', 'p']

# %%
a.sort()

# %%
print(a)
# Out:
# ['H', 'h', 'n', 'o', 'p', 't', 'y']

# %%
print(a.count('h'))
# Out:
# 1

# %%
print(a.index('n'))
# Out:
# 2

# %%
gugu7=[7*k for k in range(1,10)]
print(gugu7)
# Out:
# [7, 14, 21, 28, 35, 42, 49, 56, 63]

# %%
gugu72=[]
for k in range(1,10):
  gugu72.append(7*k)
print(gugu72)
# Out:
# [7, 14, 21, 28, 35, 42, 49, 56, 63]

# %%
div1=[k for k in range(1,129) if 128%k==0]
print(div1)
# Out:
# [1, 2, 4, 8, 16, 32, 64, 128]

# %%
div2=[]
for k in range(1,129):
  if 128%k==0:
    div2.append(k)
print(div2)
# Out:
# [1, 2, 4, 8, 16, 32, 64, 128]
